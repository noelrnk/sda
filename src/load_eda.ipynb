# %% [markdown]
# <div class="alert alert-success">
#     <b>Sports Data Analytics</b> <br>
#     instructed by Martin Rumo <br>
#     as part of the study programme MScIDS <br>
#     at the Lucerne University of Applied Sciences and Arts <br>
# <br>
# Created by Joël Lüscher and Noel Rinke | Submitted on the 27th of February 2023
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#FA-Women's-Super-League-Analysis" data-toc-modified-id="FA-Women's-Super-League-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>FA Women's Super League Analysis</a></span><ul class="toc-item"><li><span><a href="#Setup-&amp;-Configuration" data-toc-modified-id="Setup-&amp;-Configuration-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Setup &amp; Configuration</a></span></li></ul></li><li><span><a href="#Load-&amp;-Prepare-Data" data-toc-modified-id="Load-&amp;-Prepare-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load &amp; Prepare Data</a></span><ul class="toc-item"><li><span><a href="#Get-all-the-Match-Data-for-the-2018/19,-2019/20-&amp;-2020/21-Seasons" data-toc-modified-id="Get-all-the-Match-Data-for-the-2018/19,-2019/20-&amp;-2020/21-Seasons-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Get all the Match Data for the 2018/19, 2019/20 &amp; 2020/21 Seasons</a></span></li><li><span><a href="#Data-Overview-and-Query-Examples" data-toc-modified-id="Data-Overview-and-Query-Examples-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data Overview and Query Examples</a></span></li><li><span><a href="#Create-Match-Week-Data" data-toc-modified-id="Create-Match-Week-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Create Match Week Data</a></span><ul class="toc-item"><li><span><a href="#Match-Data" data-toc-modified-id="Match-Data-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Match Data</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # FA Women's Super League Analysis

# %% [markdown]
# This notebook includes the initial data preparation and an exploration of the data. It serves as the basis for the subsequent analysis of the 2018/19 season of Arsenal Women FC and the Chelsea Women FC.
#
# The data is sourced from [StatsBomb](https://statsbomb.com/) and accessed using the StatsBomb API for which a function is implemented in the [mplsoccer](https://mplsoccer.readthedocs.io/en/latest/index.html) Python library. StatsBomb is a UK based sports analytics firm and the source of data for a lot of companies in the field of sports analytics. Further information about the StatsBomb data is provided in the [StatsBomb Open Data GitHub repository](https://github.com/statsbomb/open-data). The data dictionary for the events data, which is loaded and used for the analysis, can be found [here](https://github.com/statsbomb/open-data/blob/master/doc/Open%20Data%20Events%20v4.0.0.pdf).
#
# Following this notebook, a Streamlit app is created which consists of separate modules for the data preparation and the visualizations to limit the code in the app.py script. The following image shows the content of this submission:

# %% [markdown]
# ![image](img/sda_process.png)

# %% [markdown]
# ## Setup & Configuration

# %%
# !pip install statsbomb
# !pip install mplsoccer
# Out:
# Requirement already satisfied: statsbomb in c:\users\noelrinke\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: requests in c:\users\noelrinke\anaconda3\lib\site-packages (from statsbomb) (2.28.1)
# Requirement already satisfied: pandas in c:\users\noelrinke\anaconda3\lib\site-packages (from statsbomb) (1.4.4)
# Requirement already satisfied: PyYAML in c:\users\noelrinke\anaconda3\lib\site-packages (from statsbomb) (6.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\noelrinke\anaconda3\lib\site-packages (from pandas->statsbomb) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from pandas->statsbomb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from pandas->statsbomb) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->statsbomb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->statsbomb) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->statsbomb) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->statsbomb) (1.26.13)
# Requirement already satisfied: six>=1.5 in c:\users\noelrinke\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->statsbomb) (1.16.0)
# Requirement already satisfied: mplsoccer in c:\users\noelrinke\anaconda3\lib\site-packages (1.1.10)
# Requirement already satisfied: pillow in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (9.2.0)
# Requirement already satisfied: matplotlib in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (3.6.2)
# Requirement already satisfied: numpy in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (1.21.5)
# Requirement already satisfied: scipy in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (1.9.3)
# Requirement already satisfied: requests in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (2.28.1)
# Requirement already satisfied: seaborn in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (0.12.1)
# Requirement already satisfied: pandas in c:\users\noelrinke\anaconda3\lib\site-packages (from mplsoccer) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from matplotlib->mplsoccer) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from pandas->mplsoccer) (2022.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->mplsoccer) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->mplsoccer) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->mplsoccer) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\noelrinke\anaconda3\lib\site-packages (from requests->mplsoccer) (2022.9.24)
# Requirement already satisfied: six>=1.5 in c:\users\noelrinke\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplsoccer) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsbomb as sb
from mplsoccer import Sbopen
from collections import defaultdict

# %%
# Pandas configuration
pd.options.display.precision = 2  # number of decimals shown
pd.options.display.max_rows = 100  # max number of rows shown
pd.options.display.max_columns = 100  # max number of columns shown
pd.options.display.max_colwidth = 60  # max width of cells

# %% [markdown]
# # Load & Prepare Data

# %% [markdown]
# The FA Women's Super League can be loaded using the competition_id 37. There are three seasons available for the FA Women's Super League as can be seen below.

# %%
comps = sb.Competitions()
json_data = comps.data  # underlying json data
df = comps.get_dataframe()
df[df['competition_id'] == 37]
# Out:
#     competition_id  season_id country_name         competition_name  \
# 15              37         90      England  FA Women's Super League
# 16              37         42      England  FA Women's Super League
# 17              37          4      England  FA Women's Super League
#
#    competition_gender  competition_youth  competition_international  \
# 15             female              False                      False
# 16             female              False                      False
# 17             female              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 15   2020/2021  2023-02-25T14:52:09.326729  2021-06-13T16:17:31.694
# 16   2019/2020  2023-02-25T12:45:18.376026  2021-06-13T16:17:31.694
# 17   2018/2019  2022-12-01T11:41:40.025541  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 15                None  2023-02-25T14:52:09.326729
# 16                None  2023-02-25T12:45:18.376026
# 17                None  2022-12-01T11:41:40.025541

# %% [markdown]
# ## Get all the Match Data for the 2018/19, 2019/20 & 2020/21 Seasons

# %% [markdown]
# In the following two code cells, the data is downloaded, read as pandas dataframe and also saved as csv. A check is implemented whether the data was previously downloaded. If this is the case, the data is loaded from the directory.

# %%
def get_team_matches(parser, competition_id, season_id, team_name):
    ''' Get all the matches '''
    df_season = parser.match(competition_id=competition_id, season_id=season_id)
    df_team = df_season[(df_season['home_team_name'] == team_name) |
                      (df_season['away_team_name'] == team_name)]
    return df_team


def get_events_data(parser, match_files):
    ''' Get the events data based on the match ids'''
    parser = Sbopen()
    df_match_files = pd.concat([parser.event(file)[0] for file in match_files])
    return df_match_files


def add_match_date(df_events, df_season):
    ''' Add match data to the events '''
    df = df_events.merge(df_season[['match_id', 'match_week', 'match_date']], on='match_id')
    return df

# %%
import os.path
import os
import pandas as pd

folder_name = "data"

# Create the folder "data" if not exists
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
else:
    print(f"Folder '{folder_name}' already exists.")

# Instantiate a parser object
parser = Sbopen()

cfc_files_lst = ['./data/events_18_19_cfc.csv', './data/events_19_20_cfc.csv', './data/events_20_21_cfc.csv']
afc_files_lst = ['./data/events_18_19_afc.csv', './data/events_19_20_afc.csv', './data/events_20_21_afc.csv']
season_id_lst = [4, 42, 90]


def load_data(file, season_id, team_name, df_name_prefix, df_events_prefix, parser, extension=".csv"):
    if os.path.isfile(file):
        print(f"{file} exists.. start loading the data from csv")
        df = pd.read_csv(file)
        df_name = df_name_prefix + file.split('/')[-1].split('.')[0]
        globals()[df_name] = df
    else:
        print(f"{file} does not exist in directory.. start loading the data from Statsbomb")
        folder, file_name = os.path.split(file)
        file_name_without_extension, _ = os.path.splitext(file_name)
        result = file_name_without_extension.split("_")[-3:]
        season_team = "_".join(result)
        df = get_team_matches(parser, competition_id=37, season_id=season_id, team_name=team_name)
        df_name = df_events_prefix + season_team
        df_events = get_events_data(parser, match_files=df['match_id'].to_list())
        df_events = add_match_date(df_events, df)
        csv_name = df_name[len(df_events_prefix):]
        df_events.to_csv("./data/events_" + csv_name + extension, index=False)
        df_name = df_name_prefix + file.split('/')[-1].split('.')[0]
        globals()[df_name] = df_events

# Load Chelsea FCW events data
for file, season_id in zip(cfc_files_lst, season_id_lst):
    load_data(file, season_id, 'Chelsea FCW', "df_", "df_events_", parser)

# Load Arsenal WFC events data
for file, season_id in zip(afc_files_lst, season_id_lst):
    load_data(file, season_id, 'Arsenal WFC', "df_", "df_events_", parser)
# Out:
# Folder 'data' already exists.
# ./data/events_18_19_cfc.csv exists.. start loading the data from csv
# C:\Users\NoelRinke\AppData\Local\Temp\ipykernel_20836\3057302906.py:24: DtypeWarning: Columns (52,56,57,58,59,62,65,66,69,70,73,74,75,78,79,80,81,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# ./data/events_19_20_cfc.csv exists.. start loading the data from csv
# C:\Users\NoelRinke\AppData\Local\Temp\ipykernel_20836\3057302906.py:24: DtypeWarning: Columns (41,55,57,59,60,61,62,65,68,69,71,72,73,75,77,79,80,81,82,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# ./data/events_20_21_cfc.csv exists.. start loading the data from csv
# C:\Users\NoelRinke\AppData\Local\Temp\ipykernel_20836\3057302906.py:24: DtypeWarning: Columns (55,57,58,60,61,66,67,68,71,72,73,74,75,76,77,79,80,81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# ./data/events_18_19_afc.csv exists.. start loading the data from csv
# C:\Users\NoelRinke\AppData\Local\Temp\ipykernel_20836\3057302906.py:24: DtypeWarning: Columns (54,55,59,60,63,64,70,71,72,75,76,78,79,80,82,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# ./data/events_19_20_afc.csv exists.. start loading the data from csv
# C:\Users\NoelRinke\AppData\Local\Temp\ipykernel_20836\3057302906.py:24: DtypeWarning: Columns (59,61,62,66,69,70,74,75,76,77,78,79,80,82,83) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# ./data/events_20_21_afc.csv exists.. start loading the data from csv
# C:\Users\NoelRinke\AppData\Local\Temp\ipykernel_20836\3057302906.py:24: DtypeWarning: Columns (56,61,62,63,69,70,73,75,76,78,79,80,81,82,83,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %% [markdown]
# Having downloaded the events dataframes, we would like to check if the data was imported successfully and if the number of match weeks is correct. The number of matches played by each team varied in the three seasons analysed in this report. The 2018/19 season was played with 11 teams following the change to a fully professional league for the first time. The 2019/20 season was halted after 15 matches due to the Covid-19 pandemic.

# %%
# Check if all match days are available
assert len(df_events_18_19_cfc['match_week'].unique()) == 20, f"Number of league matches does not correspond to 20, got: {len(df_season_18_19_cfc)}"
assert len(df_events_19_20_cfc['match_week'].unique()) == 15, f"Number of league matches does not correspond to 15, got: {len(df_season_19_20_cfc)}"
assert len(df_events_20_21_cfc['match_week'].unique()) == 22, f"Number of league matches does not correspond to 22, got: {len(df_season_20_21_cfc)}"

# %%
df_events_20_21_cfc.head(1)
# Out:
#                                      id  index  period timestamp  minute  \
# 0  e89618d8-f743-4c69-b267-8d06ae645927      1       1  00:00:00       0
#
#    second  possession  duration  match_id  type_id    type_name  \
# 0       0           1       0.0   3775581       35  Starting XI
#
#    possession_team_id possession_team_name  play_pattern_id play_pattern_name  \
# 0                 971          Chelsea FCW                1      Regular Play
#
#    team_id    team_name  tactics_formation  player_id player_name  \
# 0      971  Chelsea FCW              433.0        NaN         NaN
#
#    position_id position_name  pass_recipient_id pass_recipient_name  \
# 0          NaN           NaN                NaN                 NaN
#
#    pass_length  pass_angle  pass_height_id pass_height_name  end_x  end_y  \
# 0          NaN         NaN             NaN              NaN    NaN    NaN
#
#    body_part_id body_part_name  sub_type_id sub_type_name   x   y  outcome_id  \
# 0           NaN            NaN          NaN           NaN NaN NaN         NaN
#
#   outcome_name  under_pressure  out pass_cross aerial_won  counterpress  \
# 0          NaN             NaN  NaN        NaN        NaN           NaN
#
#   pass_switch  off_camera  technique_id technique_name  \
# 0         NaN         NaN           NaN            NaN
#
#   ball_recovery_recovery_failure  shot_statsbomb_xg  goalkeeper_position_id  \
# 0                            NaN                NaN                     NaN
#
#   goalkeeper_position_name pass_assisted_shot_id pass_shot_assist  \
# 0                      NaN                   NaN              NaN
#
#   shot_key_pass_id  end_z shot_redirect shot_first_time  \
# 0              NaN    NaN           NaN             NaN
#
#   injury_stoppage_in_chain block_offensive pass_goal_assist dribble_overrun  \
# 0                      NaN             NaN              NaN             NaN
#
#   ball_recovery_offensive dribble_nutmeg  substitution_replacement_id  \
# 0                     NaN            NaN                          NaN
#
#   substitution_replacement_name foul_won_defensive foul_committed_advantage  \
# 0                           NaN                NaN                      NaN
#
#   foul_won_advantage pass_miscommunication pass_cut_back  \
# 0                NaN                   NaN           NaN
#
#    foul_committed_card_id foul_committed_card_name shot_one_on_one  \
# 0                     NaN                      NaN             NaN
#
#   dribble_no_touch pass_deflected shot_open_goal foul_committed_offensive  \
# 0              NaN            NaN            NaN                      NaN
#
#   pass_no_touch  bad_behaviour_card_id bad_behaviour_card_name  \
# 0           NaN                    NaN                     NaN
#
#   block_deflection block_save_block foul_committed_penalty foul_won_penalty  \
# 0              NaN              NaN                    NaN              NaN
#
#   shot_deflected shot_follows_dribble  match_week  match_date
# 0            NaN                  NaN          18  2021-03-28

# %%
# Check if all match days are available
assert len(df_events_18_19_afc['match_week'].unique()) == 20, f"Number of league matches does not correspond to 20, got: {len(df_season_18_19_afc)}"
assert len(df_events_19_20_afc['match_week'].unique()) == 15, f"Number of league matches does not correspond to 15, got: {len(df_season_19_20_afc)}"
assert len(df_events_20_21_afc['match_week'].unique()) == 22, f"Number of league matches does not correspond to 22, got: {len(df_season_20_21_afc)}"

# %%
df_events_18_19_cfc['match_week']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 68958    16
# 68959    16
# 68960    16
# 68961    16
# 68962    16
# Name: match_week, Length: 68963, dtype: int64

# %%
df_events_20_21_afc.head(1)
# Out:
#                                      id  index  period timestamp  minute  \
# 0  f51b1630-d1a8-4837-97b0-de862f0e299a      1       1  00:00:00       0
#
#    second  possession  duration  match_id  type_id    type_name  \
# 0       0           1       0.0   3775648       35  Starting XI
#
#    possession_team_id possession_team_name  play_pattern_id play_pattern_name  \
# 0                2647          Aston Villa                1      Regular Play
#
#    team_id    team_name  tactics_formation  player_id player_name  \
# 0     2647  Aston Villa              352.0        NaN         NaN
#
#    position_id position_name  pass_recipient_id pass_recipient_name  \
# 0          NaN           NaN                NaN                 NaN
#
#    pass_length  pass_angle  pass_height_id pass_height_name  end_x  end_y  \
# 0          NaN         NaN             NaN              NaN    NaN    NaN
#
#    body_part_id body_part_name  sub_type_id sub_type_name   x   y  \
# 0           NaN            NaN          NaN           NaN NaN NaN
#
#    under_pressure  outcome_id outcome_name  counterpress pass_cross  \
# 0             NaN         NaN          NaN           NaN        NaN
#
#   aerial_won pass_assisted_shot_id pass_shot_assist  shot_statsbomb_xg  \
# 0        NaN                   NaN              NaN                NaN
#
#   shot_key_pass_id  technique_id technique_name  goalkeeper_position_id  \
# 0              NaN           NaN            NaN                     NaN
#
#   goalkeeper_position_name  out  off_camera pass_switch pass_cut_back  \
# 0                      NaN  NaN         NaN         NaN           NaN
#
#   ball_recovery_recovery_failure foul_won_defensive pass_deflected  end_z  \
# 0                            NaN                NaN            NaN    NaN
#
#   foul_committed_advantage foul_won_advantage shot_first_time block_offensive  \
# 0                      NaN                NaN             NaN             NaN
#
#   pass_no_touch pass_miscommunication pass_goal_assist  \
# 0           NaN                   NaN              NaN
#
#    substitution_replacement_id substitution_replacement_name block_deflection  \
# 0                          NaN                           NaN              NaN
#
#   dribble_nutmeg shot_one_on_one shot_open_goal  foul_committed_card_id  \
# 0            NaN             NaN            NaN                     NaN
#
#   foul_committed_card_name injury_stoppage_in_chain dribble_overrun  \
# 0                      NaN                      NaN             NaN
#
#   foul_committed_penalty foul_won_penalty  bad_behaviour_card_id  \
# 0                    NaN              NaN                    NaN
#
#   bad_behaviour_card_name foul_committed_offensive shot_follows_dribble  \
# 0                     NaN                      NaN                  NaN
#
#   ball_recovery_offensive block_save_block shot_redirect shot_deflected  \
# 0                     NaN              NaN           NaN            NaN
#
#   dribble_no_touch  match_week  match_date
# 0              NaN          11  2021-02-28

# %% [markdown]
# ## Data Overview and Query Examples

# %%
df_events_18_19_cfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68963 entries, 0 to 68962
# Data columns (total 87 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              68963 non-null  object
#  1   index                           68963 non-null  int64
#  2   period                          68963 non-null  int64
#  3   timestamp                       68963 non-null  object
#  4   minute                          68963 non-null  int64
#  5   second                          68963 non-null  int64
#  6   possession                      68963 non-null  int64
#  7   duration                        50977 non-null  float64
#  8   match_id                        68963 non-null  int64
#  9   type_id                         68963 non-null  int64
#  10  type_name                       68963 non-null  object
#  11  possession_team_id              68963 non-null  int64
#  12  possession_team_name            68963 non-null  object
#  13  play_pattern_id                 68963 non-null  int64
#  14  play_pattern_name               68963 non-null  object
#  15  team_id                         68963 non-null  int64
#  16  team_name                       68963 non-null  object
#  17  tactics_formation               88 non-null     float64
#  18  player_id                       68662 non-null  float64
#  19  player_name                     68662 non-null  object
#  20  position_id                     68662 non-null  float64
#  21  position_name                   68662 non-null  object
#  22  pass_recipient_id               17463 non-null  float64
#  23  pass_recipient_name             17463 non-null  object
#  24  pass_length                     19321 non-null  float64
#  25  pass_angle                      19321 non-null  float64
#  26  pass_height_id                  19321 non-null  float64
#  27  pass_height_name                19321 non-null  object
#  28  end_x                           35907 non-null  float64
#  29  end_y                           35907 non-null  float64
#  30  body_part_id                    18760 non-null  float64
#  31  body_part_name                  18760 non-null  object
#  32  sub_type_id                     6990 non-null   float64
#  33  sub_type_name                   6990 non-null   object
#  34  x                               68478 non-null  float64
#  35  y                               68478 non-null  float64
#  36  under_pressure                  13897 non-null  float64
#  37  outcome_id                      11259 non-null  float64
#  38  outcome_name                    11259 non-null  object
#  39  pass_assisted_shot_id           418 non-null    object
#  40  pass_shot_assist                374 non-null    object
#  41  technique_id                    896 non-null    float64
#  42  technique_name                  896 non-null    object
#  43  shot_statsbomb_xg               569 non-null    float64
#  44  shot_key_pass_id                418 non-null    object
#  45  goalkeeper_position_id          568 non-null    float64
#  46  goalkeeper_position_name        568 non-null    object
#  47  pass_cross                      438 non-null    object
#  48  counterpress                    2148 non-null   float64
#  49  ball_recovery_recovery_failure  201 non-null    object
#  50  pass_switch                     501 non-null    object
#  51  shot_first_time                 92 non-null     object
#  52  pass_goal_assist                44 non-null     object
#  53  end_z                           387 non-null    float64
#  54  dribble_nutmeg                  20 non-null     object
#  55  aerial_won                      428 non-null    object
#  56  dribble_overrun                 33 non-null     object
#  57  pass_backheel                   43 non-null     object
#  58  pass_deflected                  18 non-null     object
#  59  block_deflection                8 non-null      object
#  60  substitution_replacement_id     103 non-null    float64
#  61  substitution_replacement_name   103 non-null    object
#  62  shot_one_on_one                 30 non-null     object
#  63  foul_committed_advantage        22 non-null     object
#  64  foul_won_advantage              22 non-null     object
#  65  injury_stoppage_in_chain        13 non-null     object
#  66  foul_committed_offensive        10 non-null     object
#  67  foul_won_defensive              78 non-null     object
#  68  bad_behaviour_card_id           1 non-null      float64
#  69  bad_behaviour_card_name         1 non-null      object
#  70  ball_recovery_offensive         6 non-null      object
#  71  pass_cut_back                   39 non-null     object
#  72  off_camera                      357 non-null    float64
#  73  foul_won_penalty                3 non-null      object
#  74  block_offensive                 11 non-null     object
#  75  shot_deflected                  4 non-null      object
#  76  foul_committed_card_id          29 non-null     float64
#  77  foul_committed_card_name        29 non-null     object
#  78  pass_miscommunication           19 non-null     object
#  79  block_save_block                7 non-null      object
#  80  shot_open_goal                  4 non-null      object
#  81  foul_committed_penalty          3 non-null      object
#  82  out                             102 non-null    float64
#  83  pass_no_touch                   2 non-null      object
#  84  shot_redirect                   3 non-null      object
#  85  match_week                      68963 non-null  int64
#  86  match_date                      68963 non-null  object
# dtypes: float64(26), int64(11), object(50)
# memory usage: 45.8+ MB

# %%
df_events_18_19_cfc[df_events_18_19_cfc['player_name'].notna() & 
                    df_events_18_19_cfc['player_name'].str.contains('Kirby')].head(1)
# Out:
#                                       id  index  period        timestamp  \
# 34  f55b153d-56db-4ccc-8117-d90185576727     34       1  00:00:42.113000
#
#     minute  second  possession  duration  match_id  type_id     type_name  \
# 34       0      42           4       NaN      7298       42  Ball Receipt
#
#     possession_team_id possession_team_name  play_pattern_id  \
# 34                 971          Chelsea FCW                6
#
#    play_pattern_name  team_id    team_name  tactics_formation  player_id  \
# 34      From Counter      971  Chelsea FCW                NaN     4641.0
#
#         player_name  position_id         position_name  pass_recipient_id  \
# 34  Francesca Kirby         22.0  Right Center Forward                NaN
#
#    pass_recipient_name  pass_length  pass_angle  pass_height_id  \
# 34                 NaN          NaN         NaN             NaN
#
#    pass_height_name  end_x  end_y  body_part_id body_part_name  sub_type_id  \
# 34              NaN    NaN    NaN           NaN            NaN          NaN
#
#    sub_type_name     x     y  under_pressure  outcome_id outcome_name  \
# 34           NaN  95.0  23.0             NaN         NaN          NaN
#
#    pass_assisted_shot_id pass_shot_assist  technique_id technique_name  \
# 34                   NaN              NaN           NaN            NaN
#
#     shot_statsbomb_xg shot_key_pass_id  goalkeeper_position_id  \
# 34                NaN              NaN                     NaN
#
#    goalkeeper_position_name pass_cross  counterpress  \
# 34                      NaN        NaN           NaN
#
#    ball_recovery_recovery_failure pass_switch shot_first_time  \
# 34                            NaN         NaN             NaN
#
#    pass_goal_assist  end_z dribble_nutmeg aerial_won dribble_overrun  \
# 34              NaN    NaN            NaN        NaN             NaN
#
#    pass_backheel pass_deflected block_deflection  substitution_replacement_id  \
# 34           NaN            NaN              NaN                          NaN
#
#    substitution_replacement_name shot_one_on_one foul_committed_advantage  \
# 34                           NaN             NaN                      NaN
#
#    foul_won_advantage injury_stoppage_in_chain foul_committed_offensive  \
# 34                NaN                      NaN                      NaN
#
#    foul_won_defensive  bad_behaviour_card_id bad_behaviour_card_name  \
# 34                NaN                    NaN                     NaN
#
#    ball_recovery_offensive pass_cut_back  off_camera foul_won_penalty  \
# 34                     NaN           NaN         NaN              NaN
#
#    block_offensive shot_deflected  foul_committed_card_id  \
# 34             NaN            NaN                     NaN
#
#    foul_committed_card_name pass_miscommunication block_save_block  \
# 34                      NaN                   NaN              NaN
#
#    shot_open_goal foul_committed_penalty  out pass_no_touch shot_redirect  \
# 34            NaN                    NaN  NaN           NaN           NaN
#
#     match_week  match_date
# 34           0  2018-02-24

# %%
df_events_18_19_cfc[df_events_18_19_cfc['outcome_name'].notna() & 
                    df_events_18_19_cfc['outcome_name'].str.contains('Goal')].head(1)
# Out:
#                                        id  index  period        timestamp  \
# 256  3f0fc8e9-a09f-480a-9396-132e1ca05ec5    256       1  00:05:46.380000
#
#      minute  second  possession  duration  match_id  type_id type_name  \
# 256       5      46          16      1.48      7298       16      Shot
#
#      possession_team_id possession_team_name  play_pattern_id  \
# 256                 971          Chelsea FCW                2
#
#     play_pattern_name  team_id    team_name  tactics_formation  player_id  \
# 256       From Corner      971  Chelsea FCW                NaN     4642.0
#
#        player_name  position_id      position_name  pass_recipient_id  \
# 256  Millie Bright          3.0  Right Center Back                NaN
#
#     pass_recipient_name  pass_length  pass_angle  pass_height_id  \
# 256                 NaN          NaN         NaN             NaN
#
#     pass_height_name  end_x  end_y  body_part_id body_part_name  sub_type_id  \
# 256              NaN  120.0   43.2          38.0      Left Foot         87.0
#
#     sub_type_name      x     y  under_pressure  outcome_id outcome_name  \
# 256     Open Play  108.0  32.0             1.0        97.0         Goal
#
#     pass_assisted_shot_id pass_shot_assist  technique_id technique_name  \
# 256                   NaN              NaN          93.0         Normal
#
#      shot_statsbomb_xg                      shot_key_pass_id  \
# 256               0.07  e3effe10-23f0-413d-81e3-a468b90091b2
#
#      goalkeeper_position_id goalkeeper_position_name pass_cross  counterpress  \
# 256                     NaN                      NaN        NaN           NaN
#
#     ball_recovery_recovery_failure pass_switch shot_first_time  \
# 256                            NaN         NaN            True
#
#     pass_goal_assist  end_z dribble_nutmeg aerial_won dribble_overrun  \
# 256              NaN    2.0            NaN        NaN             NaN
#
#     pass_backheel pass_deflected block_deflection  \
# 256           NaN            NaN              NaN
#
#      substitution_replacement_id substitution_replacement_name  \
# 256                          NaN                           NaN
#
#     shot_one_on_one foul_committed_advantage foul_won_advantage  \
# 256             NaN                      NaN                NaN
#
#     injury_stoppage_in_chain foul_committed_offensive foul_won_defensive  \
# 256                      NaN                      NaN                NaN
#
#      bad_behaviour_card_id bad_behaviour_card_name ball_recovery_offensive  \
# 256                    NaN                     NaN                     NaN
#
#     pass_cut_back  off_camera foul_won_penalty block_offensive shot_deflected  \
# 256           NaN         NaN              NaN             NaN            NaN
#
#      foul_committed_card_id foul_committed_card_name pass_miscommunication  \
# 256                     NaN                      NaN                   NaN
#
#     block_save_block shot_open_goal foul_committed_penalty  out pass_no_touch  \
# 256              NaN            NaN                    NaN  NaN           NaN
#
#     shot_redirect  match_week  match_date
# 256           NaN           0  2018-02-24

# %%
# Group the data by match_week and count the number of goals for each match_week
df_events_19_20_cfc[df_events_18_19_cfc["outcome_name"] == "Goal"].groupby("match_week")["type_name"].count().to_dict()
# Out:
# {1: 5,
#  2: 1,
#  3: 3,
#  4: 1,
#  5: 1,
#  6: 3,
#  7: 4,
#  9: 3,
#  10: 4,
#  11: 2,
#  12: 2,
#  13: 3,
#  14: 3,
#  16: 2,
#  17: 6}

# %%
df_events_18_19_cfc[(df_events_18_19_cfc['type_name'] == 'Pass')].head(1)
# Out:
#                                      id  index  period        timestamp  \
# 5  2a456ec2-352c-499b-b5cc-e68bf84c7e9a      5       1  00:00:00.100000
#
#    minute  second  possession  duration  match_id  type_id type_name  \
# 5       0       0           2       0.0      7298       30      Pass
#
#    possession_team_id possession_team_name  play_pattern_id play_pattern_name  \
# 5                 971          Chelsea FCW                9     From Kick Off
#
#    team_id    team_name  tactics_formation  player_id player_name  \
# 5      971  Chelsea FCW                NaN     4647.0   So-Yun Ji
#
#    position_id    position_name  pass_recipient_id pass_recipient_name  \
# 5         14.0  Center Midfield             4659.0     Ramona Bachmann
#
#    pass_length  pass_angle  pass_height_id pass_height_name  end_x  end_y  \
# 5         3.61       -0.98             1.0      Ground Pass   63.0   37.0
#
#    body_part_id body_part_name  sub_type_id sub_type_name     x     y  \
# 5          40.0     Right Foot         65.0      Kick Off  61.0  40.0
#
#    under_pressure  outcome_id outcome_name pass_assisted_shot_id  \
# 5             NaN         NaN          NaN                   NaN
#
#   pass_shot_assist  technique_id technique_name  shot_statsbomb_xg  \
# 5              NaN           NaN            NaN                NaN
#
#   shot_key_pass_id  goalkeeper_position_id goalkeeper_position_name  \
# 5              NaN                     NaN                      NaN
#
#   pass_cross  counterpress ball_recovery_recovery_failure pass_switch  \
# 5        NaN           NaN                            NaN         NaN
#
#   shot_first_time pass_goal_assist  end_z dribble_nutmeg aerial_won  \
# 5             NaN              NaN    NaN            NaN        NaN
#
#   dribble_overrun pass_backheel pass_deflected block_deflection  \
# 5             NaN           NaN            NaN              NaN
#
#    substitution_replacement_id substitution_replacement_name shot_one_on_one  \
# 5                          NaN                           NaN             NaN
#
#   foul_committed_advantage foul_won_advantage injury_stoppage_in_chain  \
# 5                      NaN                NaN                      NaN
#
#   foul_committed_offensive foul_won_defensive  bad_behaviour_card_id  \
# 5                      NaN                NaN                    NaN
#
#   bad_behaviour_card_name ball_recovery_offensive pass_cut_back  off_camera  \
# 5                     NaN                     NaN           NaN         NaN
#
#   foul_won_penalty block_offensive shot_deflected  foul_committed_card_id  \
# 5              NaN             NaN            NaN                     NaN
#
#   foul_committed_card_name pass_miscommunication block_save_block  \
# 5                      NaN                   NaN              NaN
#
#   shot_open_goal foul_committed_penalty  out pass_no_touch shot_redirect  \
# 5            NaN                    NaN  NaN           NaN           NaN
#
#    match_week  match_date
# 5           0  2018-02-24

# %%
df_events_18_19_cfc['outcome_name'].unique()
# Out:
# array([nan, 'Incomplete', 'Complete', 'Blocked', 'Lost Out',
#        'In Play Safe', 'Lost In Play', 'Won', 'Success In Play', 'Goal',
#        'No Touch', 'Out', 'Pass Offside', 'Clear', 'Off T', 'Saved',
#        'In Play Danger', 'Unknown', 'Tactical', 'Success', 'Touched Out',
#        'Wayward', 'Claim', 'Saved Twice', 'Touched In', 'Success Out',
#        'Injury', 'Post', 'Lost', 'Success To Team', 'Injury Clearance',
#        'Success To Opposition', 'Fail', 'Punched out', 'Collected Twice'],
#       dtype=object)

# %%
df_events_18_19_cfc['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Ball Receipt', 'Pass', 'Carry',
#        'Pressure', 'Miscontrol', 'Block', 'Ball Recovery',
#        'Dribbled Past', 'Dribble', 'Shot', 'Goal Keeper', 'Clearance',
#        'Duel', 'Dispossessed', 'Camera On', 'Interception', 'Shield',
#        'Foul Committed', 'Foul Won', 'Offside', 'Tactical Shift',
#        'Injury Stoppage', 'Player Off', 'Player On', 'Half End',
#        'Substitution', 'Error', 'Bad Behaviour', 'Camera off',
#        'Referee Ball-Drop', '50/50'], dtype=object)

# %%
# use rank to give each date a number that increases with the date
df_events_18_19_cfc['date_number'] = df_events_18_19_cfc['match_date'].rank(method='dense').astype(int)
df_events_18_19_afc['date_number'] = df_events_18_19_afc['match_date'].rank(method='dense').astype(int)

# %%
len(df_events_18_19_afc['date_number'].unique())
# Out:
# 20

# %% [markdown]
# ## Create Match Week Data

# %% [markdown]
# In the following, the outcome_name and type_name of the events dataframes are used to aggregate the data for each match week and both teams.

# %%
def get_match_week_stat(df, team_name, variable):
    ''' Returns a list with the specified outcome count for each match week.
        If the outcome_name does not occur, the value 0 is added as value to the match_week. '''
    match_weeks = range(1, df["date_number"].max() + 1)
    dct = defaultdict(int)
    for match_week in match_weeks:
        dct[match_week-1] = df[(df["date_number"] == match_week) &
                             (df["team_name"] == team_name) &
                             ((df["outcome_name"] == variable) | (df["type_name"] == variable))].shape[0]
    df = pd.DataFrame.from_dict(dict(dct), orient='index', columns=[variable])
    return df[variable].tolist()


def get_match_week_stat_op(df, team_name, variable):
    ''' Returns a list with the specified outcome count for each match week for the opposing team.
        If the outcome_name does not occur, the value 0 is added as value to the match_week. '''
    match_weeks = range(df["date_number"].min(), df["date_number"].max() + 1)
    dct = defaultdict(int)
    for match_week in match_weeks:
        dct[match_week-1] = df[(df["date_number"] == match_week) &
                             (df["team_name"] != team_name) & ((df["outcome_name"] == variable) | (df["type_name"] == variable))].shape[0]
    df = pd.DataFrame.from_dict(dict(dct), orient='index', columns=[variable])
    return df[variable].tolist()


def get_match_week_stat_nested_calc(df, team_name, event_type, var_type, calc):
    if calc == 'count':
        return df[(df['type_name'] == event_type) &
                  (df['team_name'] == team_name)].groupby('date_number').count()[var_type].tolist()
    elif calc == 'sum':
        return df[(df['type_name'] == event_type) & 
                  (df['team_name'] == team_name)].groupby('date_number').sum()[var_type].tolist()
    elif calc == 'mean':
        return df[(df['type_name'] == event_type) &
                  (df['team_name'] == team_name)].groupby('date_number').mean()[var_type].tolist()


def generate_match_week_df(df, team_name):
    goals_lst = get_match_week_stat(df, team_name, 'Goal')
    goals_conceded_lst = get_match_week_stat_op(df, team_name, 'Goal')
    shots_lst = get_match_week_stat(df, team_name, 'Shot')
    off_target_lst = get_match_week_stat(df, team_name, 'Off T')
    shot_blocked_lst = get_match_week_stat(df, team_name, 'Blocked')
    shots_saved_lst = get_match_week_stat(df, team_name, 'Saved')
    xg_lst = df.groupby('date_number').sum()['shot_statsbomb_xg'].to_list()
    subs_lst = get_match_week_stat(df, team_name, 'Substitution')
    offs_lst = get_match_week_stat(df, team_name, 'Offside')
    clear_lst = get_match_week_stat(df, team_name, 'Clearance')
    pass_length_lst = get_match_week_stat_nested_calc(df, team_name, 'Pass', 'pass_length', 'sum')
    pass_length_avg_lst = get_match_week_stat_nested_calc(df, team_name, 'Pass', 'pass_length', 'mean')
    pass_cnt_lst = get_match_week_stat_nested_calc(df, team_name, 'Pass', 'pass_length', 'count')
    matches_numbered = df['date_number'].to_list()

    df = pd.DataFrame(list(zip(goals_lst, goals_conceded_lst, shots_lst, off_target_lst, shot_blocked_lst,
                               shots_saved_lst, xg_lst, subs_lst, offs_lst, clear_lst, pass_length_lst,
                               pass_length_avg_lst, pass_cnt_lst)),
                      columns=['GoalsScored', 'GoalsConceded', 'Shots', 'ShotOffT', 'ShotsBlocked', 'ShotsSaved',
                               'ShotXG', 'Substitutions', 'Offsides', 'Clearances', 'PassLengthSum', 'PassLengthAvg',
                               'PassCnt'])

    df = df.reset_index()
    df.rename(columns={'index': 'MatchWeek'}, inplace=True)
    df = df.set_index('MatchWeek')
    df.index = df.index + 1
    return df

# %%
df_match_week_cfc_18_19 = generate_match_week_df(df_events_18_19_cfc, 'Chelsea FCW')
df_match_week_afc_18_19 = generate_match_week_df(df_events_18_19_afc, 'Arsenal WFC')

# %%
df_match_week_cfc_18_19
# Out:
#            GoalsScored  GoalsConceded  Shots  ShotOffT  ShotsBlocked  \
# MatchWeek
# 1                    2              2     25         7            11
# 2                    0              0     15         5             4
# 3                    0              0     25         9             4
# 4                    0              0     20         8             4
# 5                    2              0     24         9             6
# 6                    0              5     13         6             2
# 7                    0              0     22         6             7
# 8                    1              0     22         8             7
# 9                    2              0     15         3             6
# 10                   5              0     43        12            12
# 11                   1              0     19         5             4
# 12                   4              0     22         6             4
# 13                   3              0     23         9             4
# 14                   2              1     14         2             6
# 15                   2              3     12         3             4
# 16                   2              2     22         4             7
# 17                   6              0     19         5             4
# 18                   4              0     18         6             7
# 19                   1              1     25         9             7
# 20                   3              2     19         5             3
#
#            ShotsSaved  ShotXG  Substitutions  Offsides  Clearances  \
# MatchWeek
# 1                   5    3.98              3         4          10
# 2                   6    1.91              3         0           5
# 3                   7    1.50              2         0           0
# 4                   6    2.69              3         0           6
# 5                   7    3.08              3         0           4
# 6                   5    3.15              3         0          12
# 7                   8    2.74              3         0          10
# 8                   5    1.81              3         0          20
# 9                   3    2.23              3         0          18
# 10                 11    3.55              3         0          14
# 11                  5    2.56              2         0          22
# 12                  7    3.25              3         0          11
# 13                  6    2.97              3         0          20
# 14                  3    2.41              3         0          20
# 15                  2    2.56              3         0          15
# 16                  7    4.67              2         0          13
# 17                  4    2.84              3         0          24
# 18                  1    2.52              3         0           7
# 19                  7    2.94              3         0          38
# 20                  3    4.61              3         0          43
#
#            PassLengthSum  PassLengthAvg  PassCnt
# MatchWeek
# 1               10887.19          20.90      521
# 2                9907.90          22.99      431
# 3               16123.30          22.03      732
# 4               13774.37          23.39      589
# 5               14484.77          22.53      643
# 6               12442.04          23.04      540
# 7                9041.84          21.95      412
# 8               14617.37          22.15      660
# 9               11964.48          23.23      515
# 10              13821.96          21.10      655
# 11              11184.11          21.72      515
# 12              13159.47          22.42      587
# 13              14007.84          21.58      649
# 14               9722.21          21.14      460
# 15              11542.09          20.36      567
# 16              11765.18          21.67      543
# 17              14597.34          20.65      707
# 18              17948.85          20.44      878
# 19              10307.06          21.70      475
# 20              10855.61          22.81      476

# %% [markdown]
# ### Match Data

# %% [markdown]
# The `get_team_matches` function created above is used to get the match_id which can then be used to extract statistics for a certain match. The dataframe below shows the 2018-19 season of Chelsea FCW which contains information about the matches the team played.

# %%
df_season_cfc_18_19 = get_team_matches(parser, competition_id=37, season_id=4, team_name='Chelsea FCW')
df_season_cfc_18_19
# Out:
#     match_id match_date            kick_off  home_score  away_score  \
# 0       7298 2018-02-24 2018-02-24 20:45:00           2           2
# 3      19736 2018-10-14 2018-10-14 15:00:00           0           5
# 5      19772 2018-12-02 2018-12-02 15:00:00           1           0
# 6      19730 2018-09-30 2018-09-30 15:00:00           2           0
# 7      19794 2019-02-20 2019-02-20 20:30:00           6           0
# 8      19820 2019-05-11 2019-05-11 13:30:00           2           3
# 14     19743 2018-10-21 2018-10-21 13:30:00           0           0
# 19     19748 2018-10-28 2018-10-28 13:30:00           1           0
# 21     19785 2019-01-13 2019-01-13 13:30:00           1           2
# 23     19751 2018-11-04 2018-11-04 16:00:00           0           2
# 26     19783 2019-01-06 2019-01-06 15:00:00           3           0
# 38     19805 2019-03-31 2019-03-31 15:00:00           1           1
# 41     19760 2018-11-18 2018-11-18 15:00:00           5           0
# 48     19799 2019-03-13 2019-03-13 20:00:00           0           4
# 51     19720 2018-09-19 2018-09-19 20:00:00           0           0
# 58     19714 2018-09-09 2018-09-09 15:00:00           0           0
# 60     19726 2018-09-23 2018-09-23 15:00:00           0           0
# 70     19776 2018-12-09 2018-12-09 15:30:00           0           4
# 74     19789 2019-01-27 2019-01-27 15:00:00           2           3
# 86     19755 2019-02-10 2019-02-10 14:00:00           2           2
#
#    match_status match_status_360               last_updated  \
# 0     available        scheduled 2022-05-27 12:02:24.272045
# 3     available        scheduled 2020-07-29 05:00:00.000000
# 5     available        scheduled 2020-07-29 05:00:00.000000
# 6     available        scheduled 2020-07-29 05:00:00.000000
# 7     available        scheduled 2020-07-29 05:00:00.000000
# 8     available        scheduled 2020-07-29 05:00:00.000000
# 14    available        scheduled 2021-04-28 07:08:31.946271
# 19    available        scheduled 2020-07-29 05:00:00.000000
# 21    available        scheduled 2020-07-29 05:00:00.000000
# 23    available        scheduled 2020-07-29 05:00:00.000000
# 26    available        scheduled 2020-07-29 05:00:00.000000
# 38    available        scheduled 2020-07-29 05:00:00.000000
# 41    available        scheduled 2020-07-29 05:00:00.000000
# 48    available        scheduled 2020-07-29 05:00:00.000000
# 51    available        scheduled 2020-07-29 05:00:00.000000
# 58    available        scheduled 2020-07-29 05:00:00.000000
# 60    available        scheduled 2022-12-01 11:39:55.219781
# 70    available        scheduled 2020-07-29 05:00:00.000000
# 74    available        scheduled 2021-04-28 19:48:01.164467
# 86    available        scheduled 2022-09-12 20:52:59.538692
#
#           last_updated_360  match_week  competition_id country_name  \
# 0  2021-06-13 16:17:31.694           0              37      England
# 3  2021-06-13 16:17:31.694           5              37      England
# 5  2021-06-13 16:17:31.694          11              37      England
# 6  2021-06-13 16:17:31.694           4              37      England
# 7  2021-06-13 16:17:31.694          17              37      England
# 8  2021-06-13 16:17:31.694          22              37      England
# 14 2021-06-13 16:17:31.694           6              37      England
# 19 2021-06-13 16:17:31.694           7              37      England
# 21 2021-06-13 16:17:31.694          14              37      England
# 23 2021-06-13 16:17:31.694           8              37      England
# 26 2021-06-13 16:17:31.694          13              37      England
# 38 2021-06-13 16:17:31.694          19              37      England
# 41 2021-06-13 16:17:31.694           9              37      England
# 48 2021-06-13 16:17:31.694          18              37      England
# 51 2021-06-13 16:17:31.694           2              37      England
# 58 2021-06-13 16:17:31.694           1              37      England
# 60 2021-06-13 16:17:31.694           3              37      England
# 70 2021-06-13 16:17:31.694          12              37      England
# 74 2021-06-13 16:17:31.694          15              37      England
# 86 2021-06-13 16:17:31.694          16              37      England
#
#            competition_name  season_id season_name  home_team_id  \
# 0   FA Women's Super League          4   2018/2019           746
# 3   FA Women's Super League          4   2018/2019           971
# 5   FA Women's Super League          4   2018/2019           971
# 6   FA Women's Super League          4   2018/2019           971
# 7   FA Women's Super League          4   2018/2019           971
# 8   FA Women's Super League          4   2018/2019           974
# 14  FA Women's Super League          4   2018/2019           969
# 19  FA Women's Super League          4   2018/2019           971
# 21  FA Women's Super League          4   2018/2019           968
# 23  FA Women's Super League          4   2018/2019           972
# 26  FA Women's Super League          4   2018/2019           971
# 38  FA Women's Super League          4   2018/2019           971
# 41  FA Women's Super League          4   2018/2019           971
# 48  FA Women's Super League          4   2018/2019           966
# 51  FA Women's Super League          4   2018/2019           973
# 58  FA Women's Super League          4   2018/2019           971
# 60  FA Women's Super League          4   2018/2019           967
# 70  FA Women's Super League          4   2018/2019           965
# 74  FA Women's Super League          4   2018/2019           971
# 86  FA Women's Super League          4   2018/2019           746
#
#                 home_team_name home_team_gender home_team_group  \
# 0          Manchester City WFC           female            None
# 3                  Chelsea FCW           female            None
# 5                  Chelsea FCW           female            None
# 6                  Chelsea FCW           female            None
# 7                  Chelsea FCW           female            None
# 8                  Reading WFC           female            None
# 14         Birmingham City WFC           female            None
# 19                 Chelsea FCW           female            None
# 21                 Arsenal WFC           female            None
# 23         West Ham United LFC           female            None
# 26                 Chelsea FCW           female            None
# 38                 Chelsea FCW           female            None
# 41                 Chelsea FCW           female            None
# 48               Liverpool WFC           female            None
# 51            Bristol City WFC           female            None
# 58                 Chelsea FCW           female            None
# 60                 Everton LFC           female            None
# 70  Brighton & Hove Albion WFC           female            None
# 74                 Chelsea FCW           female            None
# 86         Manchester City WFC           female            None
#
#     home_team_country_id home_team_country_name  home_team_managers_id  \
# 0                     68                England                     30
# 3                     68                England                    152
# 5                     68                England                    152
# 6                     68                England                    152
# 7                     68                England                    152
# 8                     68                England                    144
# 14                    68                England                    128
# 19                    68                England                    152
# 21                    68                England                     31
# 23                    68                England                    139
# 26                    68                England                    152
# 38                    68                England                    152
# 41                    68                England                    152
# 48                    68                England                    623
# 51                    68                England                    143
# 58                    68                England                    152
# 60                    68                England                    146
# 70                    68                England                    149
# 74                    68                England                    152
# 86                    68                England                     30
#
#    home_team_managers_name home_team_managers_nickname home_team_managers_dob  \
# 0             Nick Cushing                Nick Cushing             1984-11-09
# 3               Emma Hayes                  Emma Hayes             1976-10-18
# 5               Emma Hayes                  Emma Hayes             1976-10-18
# 6               Emma Hayes                  Emma Hayes             1976-10-18
# 7               Emma Hayes                  Emma Hayes             1976-10-18
# 8           Kelly Chambers              Kelly Chambers             1986-01-11
# 14            Marc Skinner                Marc Skinner             1983-03-23
# 19              Emma Hayes                  Emma Hayes             1976-10-18
# 21       Joseph Montemurro           Joseph Montemurro             1969-09-13
# 23              Matt Beard                  Matt Beard             1978-01-09
# 26              Emma Hayes                  Emma Hayes             1976-10-18
# 38              Emma Hayes                  Emma Hayes             1976-10-18
# 41              Emma Hayes                  Emma Hayes             1976-10-18
# 48         Victoria Jepson             Victoria Jepson             1987-02-23
# 51            Tanya Oxtoby                Tanya Oxtoby             1982-06-15
# 58              Emma Hayes                  Emma Hayes             1976-10-18
# 60             Andy Spence                 Andy Spence             1983-01-08
# 70    Hope Patricia Powell                 Hope Powell             1966-12-08
# 74              Emma Hayes                  Emma Hayes             1976-10-18
# 86            Nick Cushing                Nick Cushing             1984-11-09
#
#     home_team_managers_country_id home_team_managers_country_name  \
# 0                              68                         England
# 3                              68                         England
# 5                              68                         England
# 6                              68                         England
# 7                              68                         England
# 8                              68                         England
# 14                             68                         England
# 19                             68                         England
# 21                             14                       Australia
# 23                             68                         England
# 26                             68                         England
# 38                             68                         England
# 41                             68                         England
# 48                             68                         England
# 51                             14                       Australia
# 58                             68                         England
# 60                             68                         England
# 70                             68                         England
# 74                             68                         England
# 86                             68                         England
#
#     away_team_id              away_team_name away_team_gender away_team_group  \
# 0            971                 Chelsea FCW           female            None
# 3            968                 Arsenal WFC           female            None
# 5            974                 Reading WFC           female            None
# 6            965  Brighton & Hove Albion WFC           female            None
# 7            973            Bristol City WFC           female            None
# 8            971                 Chelsea FCW           female            None
# 14           971                 Chelsea FCW           female            None
# 19           966               Liverpool WFC           female            None
# 21           971                 Chelsea FCW           female            None
# 23           971                 Chelsea FCW           female            None
# 26           967                 Everton LFC           female            None
# 38           972         West Ham United LFC           female            None
# 41           970             Yeovil Town LFC           female            None
# 48           971                 Chelsea FCW           female            None
# 51           971                 Chelsea FCW           female            None
# 58           746         Manchester City WFC           female            None
# 60           971                 Chelsea FCW           female            None
# 70           971                 Chelsea FCW           female            None
# 74           969         Birmingham City WFC           female            None
# 86           971                 Chelsea FCW           female            None
#
#     away_team_country_id away_team_country_name  away_team_managers_id  \
# 0                     68                England                    152
# 3                     68                England                     31
# 5                     68                England                    144
# 6                     68                England                    149
# 7                     68                England                    143
# 8                     68                England                    152
# 14                    68                England                    152
# 19                    68                England                    623
# 21                    68                England                    152
# 23                    68                England                    152
# 26                    68                England                    639
# 38                    68                England                    139
# 41                    68                England                    147
# 48                    68                England                    152
# 51                    68                England                    152
# 58                    68                England                     30
# 60                    68                England                    152
# 70                    68                England                    152
# 74                    68                England                   1817
# 86                    68                England                    152
#
#    away_team_managers_name away_team_managers_nickname away_team_managers_dob  \
# 0               Emma Hayes                  Emma Hayes             1976-10-18
# 3        Joseph Montemurro           Joseph Montemurro             1969-09-13
# 5           Kelly Chambers              Kelly Chambers             1986-01-11
# 6     Hope Patricia Powell                 Hope Powell             1966-12-08
# 7             Tanya Oxtoby                Tanya Oxtoby             1982-06-15
# 8               Emma Hayes                  Emma Hayes             1976-10-18
# 14              Emma Hayes                  Emma Hayes             1976-10-18
# 19         Victoria Jepson             Victoria Jepson             1987-02-23
# 21              Emma Hayes                  Emma Hayes             1976-10-18
# 23              Emma Hayes                  Emma Hayes             1976-10-18
# 26             Willie Kirk                 Willie Kirk             1978-06-07
# 38              Matt Beard                  Matt Beard             1978-01-09
# 41               Lee Burch                   Lee Burch             1984-06-21
# 48              Emma Hayes                  Emma Hayes             1976-10-18
# 51              Emma Hayes                  Emma Hayes             1976-10-18
# 58            Nick Cushing                Nick Cushing             1984-11-09
# 60              Emma Hayes                  Emma Hayes             1976-10-18
# 70              Emma Hayes                  Emma Hayes             1976-10-18
# 74           Marta Tejedor               Marta Tejedor             1968-12-23
# 86              Emma Hayes                  Emma Hayes             1976-10-18
#
#     away_team_managers_country_id away_team_managers_country_name  \
# 0                              68                         England
# 3                              14                       Australia
# 5                              68                         England
# 6                              68                         England
# 7                              14                       Australia
# 8                              68                         England
# 14                             68                         England
# 19                             68                         England
# 21                             68                         England
# 23                             68                         England
# 26                            201                        Scotland
# 38                             68                         England
# 41                             68                         England
# 48                             68                         England
# 51                             68                         England
# 58                             68                         England
# 60                             68                         England
# 70                             68                         England
# 74                             45                           Chile
# 86                             68                         England
#
#    metadata_data_version  competition_stage_id competition_stage_name  \
# 0                  1.0.2                     1         Regular Season
# 3                  1.0.3                     1         Regular Season
# 5                  1.0.3                     1         Regular Season
# 6                  1.0.3                     1         Regular Season
# 7                  1.0.3                     1         Regular Season
# 8                  1.1.0                     1         Regular Season
# 14                 1.0.3                     1         Regular Season
# 19                 1.0.3                     1         Regular Season
# 21                 1.0.3                     1         Regular Season
# 23                 1.0.3                     1         Regular Season
# 26                 1.0.3                     1         Regular Season
# 38                 1.1.0                     1         Regular Season
# 41                 1.0.3                     1         Regular Season
# 48                 1.1.0                     1         Regular Season
# 51                 1.0.3                     1         Regular Season
# 58                 1.0.3                     1         Regular Season
# 60                 1.0.3                     1         Regular Season
# 70                 1.0.3                     1         Regular Season
# 74                 1.0.3                     1         Regular Season
# 86                 1.0.3                     1         Regular Season
#
#     stadium_id            stadium_name  stadium_country_id  \
# 0           99        Academy Stadium                   68
# 3          132             Kingsmeadow                  68
# 5          132             Kingsmeadow                  68
# 6          132             Kingsmeadow                  68
# 7          132             Kingsmeadow                  68
# 8          577             Adams Park                   68
# 14        5332          \tARMCO Arena                   68
# 19         132             Kingsmeadow                  68
# 21         456            Meadow Park                   68
# 23        4062  The Rush Green Stadium                  68
# 26         132             Kingsmeadow                  68
# 38         132             Kingsmeadow                  68
# 41         132             Kingsmeadow                  68
# 48         579            Prenton Park                  68
# 51        4055   Stoke Gifford Stadium                  68
# 58         132             Kingsmeadow                  68
# 60         111             Haig Avenue                  68
# 70        4494      Broadfield Stadium                  68
# 74         132             Kingsmeadow                  68
# 86          99        Academy Stadium                   68
#
#    stadium_country_name  referee_id      referee_name  referee_country_id  \
# 0               England         109    Darren England                  68
# 3               England         905       Sam Purkiss                  68
# 5               England         894       Lucy Oliver                  68
# 6               England         895  Abigail Marriott                  68
# 7               England         932        Tom Bishop                  68
# 8               England         937     Abigail Byrne                  68
# 14              England         898         Amy Fearn                  68
# 19              England         893    Stacey Pearson                  68
# 21              England         566     Rebecca Welch                  68
# 23              England         897       Paul Howard                  68
# 26              England         925       Lee Brennan                  68
# 38              England         893    Stacey Pearson                  68
# 41              England         914      Kirsty Dowle                  68
# 48              England         933          Joe Hull                  68
# 51              England         893    Stacey Pearson                  68
# 58              England         566     Rebecca Welch                  68
# 60              England         567      Helen Conley                  68
# 70              England         920        David Rick                  68
# 74              England         567      Helen Conley                  68
# 86              England         931   Matthew Dicicco                  68
#
#    referee_country_name metadata_shot_fidelity_version
# 0               England                            NaN
# 3               England                            NaN
# 5               England                            NaN
# 6               England                            NaN
# 7               England                            NaN
# 8               England                              2
# 14              England                            NaN
# 19              England                            NaN
# 21              England                            NaN
# 23              England                            NaN
# 26              England                            NaN
# 38              England                              2
# 41              England                            NaN
# 48              England                            NaN
# 51              England                            NaN
# 58              England                            NaN
# 60              England                            NaN
# 70              England                            NaN
# 74              England                            NaN
# 86              England                            NaN

# %%
df_season_afc_18_19 = get_team_matches(parser, competition_id=37, season_id=4, team_name='Arsenal WFC')
df_season_afc_18_19
# Out:
#      match_id match_date            kick_off  home_score  away_score  \
# 3       19736 2018-10-14 2018-10-14 15:00:00           0           5
# 9       19766 2018-11-25 2018-11-25 13:30:00           4           1
# 11      19717 2018-09-09 2018-09-09 13:30:00           5           0
# 17      19800 2019-03-14 2019-03-14 20:30:00           4           0
# 21      19785 2019-01-13 2019-01-13 13:30:00           1           2
# 22      19749 2018-11-04 2018-11-04 13:30:00           3           1
# 29      19770 2018-12-02 2018-12-02 13:30:00           2           0
# 37      19811 2019-04-21 2019-04-21 13:30:00           2           1
# 47      19744 2018-10-28 2018-10-28 16:00:00           0           4
# 55      19722 2018-09-19 2018-09-19 20:45:00           0           7
# 63      19759 2018-11-18 2018-11-18 13:30:00           0           4
# 75      19791 2019-01-27 2019-01-27 13:30:00           0           3
# 77      19797 2019-02-20 2019-02-20 20:30:00           3           0
# 79      19781 2019-01-06 2019-01-06 13:30:00           2           4
# 91      19804 2019-03-31 2019-03-31 13:30:00           0           1
# 95      19815 2019-04-28 2019-04-28 13:15:00           0           4
# 99      19821 2019-05-11 2019-05-11 13:30:00           1           0
# 101     19741 2018-10-21 2018-10-21 15:00:00           6           0
# 103     19754 2019-03-24 2019-03-24 13:30:00           1           5
# 104     19724 2018-09-23 2018-09-23 15:00:00           4           3
#
#     match_status match_status_360               last_updated  \
# 3      available        scheduled 2020-07-29 05:00:00.000000
# 9      available        scheduled 2020-07-29 05:00:00.000000
# 11     available        scheduled 2020-07-29 05:00:00.000000
# 17     available        scheduled 2020-08-24 14:34:34.401523
# 21     available        scheduled 2020-07-29 05:00:00.000000
# 22     available        scheduled 2021-04-28 19:48:01.152793
# 29     available        scheduled 2020-07-29 05:00:00.000000
# 37     available        scheduled 2020-07-29 05:00:00.000000
# 47     available        scheduled 2020-07-29 05:00:00.000000
# 55     available        scheduled 2020-07-29 05:00:00.000000
# 63     available        scheduled 2020-07-29 05:00:00.000000
# 75     available        scheduled 2020-07-29 05:00:00.000000
# 77     available        scheduled 2020-07-29 05:00:00.000000
# 79     available        scheduled 2020-07-29 05:00:00.000000
# 91     available        scheduled 2021-04-28 19:48:01.165303
# 95     available        scheduled 2022-09-12 21:06:25.061309
# 99     available        scheduled 2020-07-29 05:00:00.000000
# 101    available        scheduled 2020-07-29 05:00:00.000000
# 103    available        scheduled 2020-07-29 05:00:00.000000
# 104    available        scheduled 2020-07-29 05:00:00.000000
#
#            last_updated_360  match_week  competition_id country_name  \
# 3   2021-06-13 16:17:31.694           5              37      England
# 9   2021-06-13 16:17:31.694          10              37      England
# 11  2021-06-13 16:17:31.694           1              37      England
# 17  2021-06-13 16:17:31.694          18              37      England
# 21  2021-06-13 16:17:31.694          14              37      England
# 22  2021-06-13 16:17:31.694           8              37      England
# 29  2021-06-13 16:17:31.694          11              37      England
# 37  2021-06-13 16:17:31.694          20              37      England
# 47  2021-06-13 16:17:31.694           7              37      England
# 55  2021-06-13 16:17:31.694           2              37      England
# 63  2021-06-13 16:17:31.694           9              37      England
# 75  2021-06-13 16:17:31.694          15              37      England
# 77  2021-06-13 16:17:31.694          17              37      England
# 79  2021-06-13 16:17:31.694          13              37      England
# 91  2021-06-13 16:17:31.694          19              37      England
# 95  2021-06-13 16:17:31.694          21              37      England
# 99  2021-06-13 16:17:31.694          22              37      England
# 101 2021-06-13 16:17:31.694           6              37      England
# 103 2021-06-13 16:17:31.694          16              37      England
# 104 2021-06-13 16:17:31.694           3              37      England
#
#             competition_name  season_id season_name  home_team_id  \
# 3    FA Women's Super League          4   2018/2019           971
# 9    FA Women's Super League          4   2018/2019           968
# 11   FA Women's Super League          4   2018/2019           968
# 17   FA Women's Super League          4   2018/2019           968
# 21   FA Women's Super League          4   2018/2019           968
# 22   FA Women's Super League          4   2018/2019           968
# 29   FA Women's Super League          4   2018/2019           746
# 37   FA Women's Super League          4   2018/2019           968
# 47   FA Women's Super League          4   2018/2019           973
# 55   FA Women's Super League          4   2018/2019           970
# 63   FA Women's Super League          4   2018/2019           967
# 75   FA Women's Super League          4   2018/2019           974
# 77   FA Women's Super League          4   2018/2019           968
# 79   FA Women's Super League          4   2018/2019           972
# 91   FA Women's Super League          4   2018/2019           969
# 95   FA Women's Super League          4   2018/2019           965
# 99   FA Women's Super League          4   2018/2019           968
# 101  FA Women's Super League          4   2018/2019           968
# 103  FA Women's Super League          4   2018/2019           966
# 104  FA Women's Super League          4   2018/2019           968
#
#                  home_team_name home_team_gender home_team_group  \
# 3                   Chelsea FCW           female            None
# 9                   Arsenal WFC           female            None
# 11                  Arsenal WFC           female            None
# 17                  Arsenal WFC           female            None
# 21                  Arsenal WFC           female            None
# 22                  Arsenal WFC           female            None
# 29          Manchester City WFC           female            None
# 37                  Arsenal WFC           female            None
# 47             Bristol City WFC           female            None
# 55              Yeovil Town LFC           female            None
# 63                  Everton LFC           female            None
# 75                  Reading WFC           female            None
# 77                  Arsenal WFC           female            None
# 79          West Ham United LFC           female            None
# 91          Birmingham City WFC           female            None
# 95   Brighton & Hove Albion WFC           female            None
# 99                  Arsenal WFC           female            None
# 101                 Arsenal WFC           female            None
# 103               Liverpool WFC           female            None
# 104                 Arsenal WFC           female            None
#
#      home_team_country_id home_team_country_name  home_team_managers_id  \
# 3                      68                England                    152
# 9                      68                England                     31
# 11                     68                England                     31
# 17                     68                England                     31
# 21                     68                England                     31
# 22                     68                England                     31
# 29                     68                England                     30
# 37                     68                England                     31
# 47                     68                England                    143
# 55                     68                England                    147
# 63                     68                England                    146
# 75                     68                England                    144
# 77                     68                England                     31
# 79                     68                England                    139
# 91                     68                England                   1817
# 95                     68                England                    149
# 99                     68                England                     31
# 101                    68                England                     31
# 103                    68                England                    623
# 104                    68                England                     31
#
#     home_team_managers_name home_team_managers_nickname  \
# 3                Emma Hayes                  Emma Hayes
# 9         Joseph Montemurro           Joseph Montemurro
# 11        Joseph Montemurro           Joseph Montemurro
# 17        Joseph Montemurro           Joseph Montemurro
# 21        Joseph Montemurro           Joseph Montemurro
# 22        Joseph Montemurro           Joseph Montemurro
# 29             Nick Cushing                Nick Cushing
# 37        Joseph Montemurro           Joseph Montemurro
# 47             Tanya Oxtoby                Tanya Oxtoby
# 55                Lee Burch                   Lee Burch
# 63              Andy Spence                 Andy Spence
# 75           Kelly Chambers              Kelly Chambers
# 77        Joseph Montemurro           Joseph Montemurro
# 79               Matt Beard                  Matt Beard
# 91            Marta Tejedor               Marta Tejedor
# 95     Hope Patricia Powell                 Hope Powell
# 99        Joseph Montemurro           Joseph Montemurro
# 101       Joseph Montemurro           Joseph Montemurro
# 103         Victoria Jepson             Victoria Jepson
# 104       Joseph Montemurro           Joseph Montemurro
#
#     home_team_managers_dob  home_team_managers_country_id  \
# 3               1976-10-18                             68
# 9               1969-09-13                             14
# 11              1969-09-13                             14
# 17              1969-09-13                             14
# 21              1969-09-13                             14
# 22              1969-09-13                             14
# 29              1984-11-09                             68
# 37              1969-09-13                             14
# 47              1982-06-15                             14
# 55              1984-06-21                             68
# 63              1983-01-08                             68
# 75              1986-01-11                             68
# 77              1969-09-13                             14
# 79              1978-01-09                             68
# 91              1968-12-23                             45
# 95              1966-12-08                             68
# 99              1969-09-13                             14
# 101             1969-09-13                             14
# 103             1987-02-23                             68
# 104             1969-09-13                             14
#
#     home_team_managers_country_name  away_team_id              away_team_name  \
# 3                           England           968                 Arsenal WFC
# 9                         Australia           965  Brighton & Hove Albion WFC
# 11                        Australia           966               Liverpool WFC
# 17                        Australia           973            Bristol City WFC
# 21                        Australia           971                 Chelsea FCW
# 22                        Australia           969         Birmingham City WFC
# 29                          England           968                 Arsenal WFC
# 37                        Australia           967                 Everton LFC
# 47                        Australia           968                 Arsenal WFC
# 55                          England           968                 Arsenal WFC
# 63                          England           968                 Arsenal WFC
# 75                          England           968                 Arsenal WFC
# 77                        Australia           970             Yeovil Town LFC
# 79                          England           968                 Arsenal WFC
# 91                            Chile           968                 Arsenal WFC
# 95                          England           968                 Arsenal WFC
# 99                        Australia           746         Manchester City WFC
# 101                       Australia           974                 Reading WFC
# 103                         England           968                 Arsenal WFC
# 104                       Australia           972         West Ham United LFC
#
#     away_team_gender away_team_group  away_team_country_id  \
# 3             female            None                    68
# 9             female            None                    68
# 11            female            None                    68
# 17            female            None                    68
# 21            female            None                    68
# 22            female            None                    68
# 29            female            None                    68
# 37            female            None                    68
# 47            female            None                    68
# 55            female            None                    68
# 63            female            None                    68
# 75            female            None                    68
# 77            female            None                    68
# 79            female            None                    68
# 91            female            None                    68
# 95            female            None                    68
# 99            female            None                    68
# 101           female            None                    68
# 103           female            None                    68
# 104           female            None                    68
#
#     away_team_country_name  away_team_managers_id away_team_managers_name  \
# 3                  England                     31       Joseph Montemurro
# 9                  England                    149    Hope Patricia Powell
# 11                 England                    154           Neil Redfearn
# 17                 England                    143            Tanya Oxtoby
# 21                 England                    152              Emma Hayes
# 22                 England                    128            Marc Skinner
# 29                 England                     31       Joseph Montemurro
# 37                 England                    639             Willie Kirk
# 47                 England                     31       Joseph Montemurro
# 55                 England                     31       Joseph Montemurro
# 63                 England                     31       Joseph Montemurro
# 75                 England                     31       Joseph Montemurro
# 77                 England                    147               Lee Burch
# 79                 England                     31       Joseph Montemurro
# 91                 England                     31       Joseph Montemurro
# 95                 England                     31       Joseph Montemurro
# 99                 England                     30            Nick Cushing
# 101                England                    144          Kelly Chambers
# 103                England                     31       Joseph Montemurro
# 104                England                    139              Matt Beard
#
#     away_team_managers_nickname away_team_managers_dob  \
# 3             Joseph Montemurro             1969-09-13
# 9                   Hope Powell             1966-12-08
# 11                Neil Redfearn             1965-06-20
# 17                 Tanya Oxtoby             1982-06-15
# 21                   Emma Hayes             1976-10-18
# 22                 Marc Skinner             1983-03-23
# 29            Joseph Montemurro             1969-09-13
# 37                  Willie Kirk             1978-06-07
# 47            Joseph Montemurro             1969-09-13
# 55            Joseph Montemurro             1969-09-13
# 63            Joseph Montemurro             1969-09-13
# 75            Joseph Montemurro             1969-09-13
# 77                    Lee Burch             1984-06-21
# 79            Joseph Montemurro             1969-09-13
# 91            Joseph Montemurro             1969-09-13
# 95            Joseph Montemurro             1969-09-13
# 99                 Nick Cushing             1984-11-09
# 101              Kelly Chambers             1986-01-11
# 103           Joseph Montemurro             1969-09-13
# 104                  Matt Beard             1978-01-09
#
#      away_team_managers_country_id away_team_managers_country_name  \
# 3                               14                       Australia
# 9                               68                         England
# 11                              68                         England
# 17                              14                       Australia
# 21                              68                         England
# 22                              68                         England
# 29                              14                       Australia
# 37                             201                        Scotland
# 47                              14                       Australia
# 55                              14                       Australia
# 63                              14                       Australia
# 75                              14                       Australia
# 77                              68                         England
# 79                              14                       Australia
# 91                              14                       Australia
# 95                              14                       Australia
# 99                              68                         England
# 101                             68                         England
# 103                             14                       Australia
# 104                             68                         England
#
#     metadata_data_version  competition_stage_id competition_stage_name  \
# 3                   1.0.3                     1         Regular Season
# 9                   1.0.3                     1         Regular Season
# 11                  1.0.3                     1         Regular Season
# 17                  1.1.0                     1         Regular Season
# 21                  1.0.3                     1         Regular Season
# 22                  1.0.3                     1         Regular Season
# 29                  1.0.3                     1         Regular Season
# 37                  1.1.0                     1         Regular Season
# 47                  1.0.3                     1         Regular Season
# 55                  1.0.3                     1         Regular Season
# 63                  1.0.3                     1         Regular Season
# 75                  1.0.3                     1         Regular Season
# 77                  1.0.3                     1         Regular Season
# 79                  1.0.3                     1         Regular Season
# 91                  1.1.0                     1         Regular Season
# 95                  1.1.0                     1         Regular Season
# 99                  1.1.0                     1         Regular Season
# 101                 1.0.3                     1         Regular Season
# 103                 1.1.0                     1         Regular Season
# 104                 1.0.3                     1         Regular Season
#
#      stadium_id                            stadium_name  stadium_country_id  \
# 3           132                             Kingsmeadow                  68
# 9           456                            Meadow Park                   68
# 11          456                            Meadow Park                   68
# 17          456                            Meadow Park                   68
# 21          456                            Meadow Park                   68
# 22          456                            Meadow Park                   68
# 29           99                        Academy Stadium                   68
# 37          456                            Meadow Park                   68
# 47         4055                   Stoke Gifford Stadium                  68
# 55         4847                         Clayson Stadium                  68
# 63          111                             Haig Avenue                  68
# 75          577                             Adams Park                   68
# 77          456                            Meadow Park                   68
# 79         4062                  The Rush Green Stadium                  68
# 91         5332                          \tARMCO Arena                   68
# 95          203  The American Express Community Stadium                  68
# 99          456                            Meadow Park                   68
# 101         456                            Meadow Park                   68
# 103         579                            Prenton Park                  68
# 104         456                            Meadow Park                   68
#
#     stadium_country_name  referee_id      referee_name  referee_country_id  \
# 3                England         905       Sam Purkiss                  68
# 9                England         915       Rob Whitton                  68
# 11               England         569  Jason Richardson                  68
# 17               England         915       Rob Whitton                  68
# 21               England         566     Rebecca Welch                  68
# 22               England         566     Rebecca Welch                  68
# 29               England         895  Abigail Marriott                  68
# 37               England         893    Stacey Pearson                  68
# 47               England         907    Daniel Lamport                  68
# 55               England         896     Scott Jackson                  68
# 63               England         894       Lucy Oliver                  68
# 75               England         894       Lucy Oliver                  68
# 77               England         914      Kirsty Dowle                  68
# 79               England         927       Will Finnie                  68
# 91               England         566     Rebecca Welch                  68
# 95               England         894       Lucy Oliver                  68
# 99               England         566     Rebecca Welch                  68
# 101              England         895  Abigail Marriott                  68
# 103              England         567      Helen Conley                  68
# 104              England         897       Paul Howard                  68
#
#     referee_country_name metadata_shot_fidelity_version
# 3                England                            NaN
# 9                England                            NaN
# 11               England                            NaN
# 17               England                            NaN
# 21               England                            NaN
# 22               England                            NaN
# 29               England                            NaN
# 37               England                              2
# 47               England                            NaN
# 55               England                            NaN
# 63               England                            NaN
# 75               England                            NaN
# 77               England                            NaN
# 79               England                            NaN
# 91               England                              2
# 95               England                              2
# 99               England                              2
# 101              England                            NaN
# 103              England                            NaN
# 104              England                            NaN
